# %%
# Cell 1: Add Project Root to Path
import sys
import os

# Get the absolute path of the 'notebooks' directory
notebook_dir = os.path.abspath('') # This gets the current dir in a notebook

# Get the parent directory (which is the project root 'chess_ai_commentary')
project_root = os.path.dirname(notebook_dir)

# Add the project root to sys.path
if project_root not in sys.path:
    sys.path.append(project_root)
    print(f"Added project root to path: {project_root}")
else:
    print(f"Project root already in path: {project_root}")
# Out:
# Added project root to path: c:\Users\Aagam\OneDrive\Desktop\ipd\model\newknight_speakai\chess_ai_commentary

# %%
import os
from src.config import STOCKFISH_PATH
from src.utils import (
    setup_environment, 
    initialize_tts_model, 
    initialize_services, 
    print_summary,
    get_pgn_source, # The interactive menu
    SAMPLE_GAMES # The sample games
)
from src.chess_analyzer import ChessAnalyzer
from src.commentary_generator import CommentaryGenerator
from src.voice_generator import VoiceGenerator
from src.pipeline import ChessCommentaryPipeline
print("✅ All project modules imported successfully!")
# Out:
# 🔄 Loading configuration...
# ✅ Configuration loaded.
#    - Stockfish Path: C:\Users\Aagam\OneDrive\Desktop\ipd\model\newknight_speakai\chess_ai_commentary\engines\stockfish\stockfish.exe
#    - Gemini API Key: Set
#    - TTS Device: cpu
# ✅ Utility functions and sample games loaded.
# ✅ Google Gemini API configured successfully.
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ✅ All project modules imported successfully!

# %%
system_device = setup_environment()
tts = initialize_tts_model(device=system_device)
initialize_services() # This just checks and prints status
print_summary(tts)
# Out:
# 1. Checking system environment...
# ✅ Device set to: CPU (from config)
# 🐍 PyTorch version: 2.8.0+cpu
#
# 2. Initializing Coqui TTS model...
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# ✅ Coqui TTS model loaded successfully!
#
# 3. Initializing Stockfish & Gemini...
# ✅ Stockfish path is valid.
# ✅ Google Gemini API is configured.
#
# =========================
# 🚀 SETUP SUMMARY 🚀
# =========================
# 🎵 TTS Model: ✅ Loaded
# ♟️  Stockfish: ✅ Path OK
# 💎 Gemini API: ✅ Set
# =========================

# %%
analyzer = ChessAnalyzer(STOCKFISH_PATH) 
commentary_gen = CommentaryGenerator()
voice_gen = VoiceGenerator(tts)

# Inject them into the main pipeline
pipeline = ChessCommentaryPipeline(analyzer, commentary_gen, voice_gen)
# Out:
# ✅ Stockfish engine initialized successfully!
# ✅ Gemini model 'gemini-2.5-flash' loaded.
# ✅ Pygame audio mixer initialized.
# ✅ VoiceGenerator ready with model.
#
# 🚀 Complete chess commentary pipeline is ready!

# %%
print("🚀 Ready to process a game.")
pgn_data, source_name = get_pgn_source() # Interactive menu

if pgn_data:
    print(f"--- Starting pipeline for {source_name} ---")
    
    # Define where to save the audio
    save_file_path = f"output/audio/{source_name.split('.')[0]}_commentary.wav"
    os.makedirs(os.path.dirname(save_file_path), exist_ok=True)

    # Run the entire pipeline using the notebook function
    pipeline.process_pgn_for_notebook(
        pgn_string=pgn_data,
        play_audio=True,
        save_path=save_file_path,
        language='en'
    )
    print(f"--- Pipeline finished. Audio saved to {save_file_path} ---")
else:
    print("❌ No PGN data provided. Exiting.")
# Out:
# 🚀 Ready to process a game.
#
# ------------------------------
# 🎯 Please choose a PGN source for analysis:
#    1. Use a built-in sample game
#    2. Load a PGN file (from 'input/pgn_files/')
#    3. Paste PGN text directly
#
# 📋 Available sample games:
#    1. quick_test
#    2. scholars_mate
#    3. immortal_game
# ✅ Selected sample: quick_test
# --- Starting pipeline for quick_test ---
#
# ==================================================
# 🎯 Starting Notebook Pipeline (with Built-in Speaker)...
# ==================================================
#
# [Step 1/2] 📊 Analyzing game moves...
# 🔄 Analyzing game with 10 moves...
#    📊 Analyzed move 10/10 (Be7)...
# ✅ Game analysis complete.
#
# [Step 2/2] ✍️ Generating AI commentary...
# 🔄 Generating batched commentary for 10 moves in English...
# ✅ All commentary generated successfully in a single batch.
#
# [Step 3/3] 🔊 Synthesizing voice audio (built-in)...
#    📂 Output directory ensured: output/audio
# 🎤 Generating audio with built-in speaker 'Claribel Dervla'...
#  > Text splitted to sentences.
# ['White kicks off the game with the aggressive e4, staking a claim in the center and opening lines for the queen and bishop!', 'A classic start!', "Black responds symmetrically with e5, immediately challenging White's central control and mirroring the opening in typical fashion.", "White develops a knight to f3, putting pressure on Black's e5 pawn and preparing for kingside castling.", 'Textbook stuff so far!', 'Black brings their knight to c6, defending the central e5 pawn and continuing the fight for central influence.', 'Solid development!', "White plays Bb5, pinning Black's knight on c6 and initiating the classic Ruy Lopez opening!", 'The tension builds already.', "Black responds with a6, questioning the bishop's position and often leading to an exchange or retreat.", 'The main line continues!', "White's bishop wisely retreats to a4, maintaining the subtle pressure along the a4-e8 diagonal.", 'No desire for an immediate exchange here.', "Black develops their kingside knight to f6, getting closer to castling and creating more pressure on White's e4 pawn.", 'A very natural move.', "White castles kingside, securing the king's safety and bringing the rook into the game.", 'A crucial developing move that everyone loves to see!', 'Black develops their bishop to e7, clearing the way for their own kingside castling and completing their initial setup.', 'Smooth sailing in the opening for both sides!']
#  > Processing time: 654.8103580474854
#  > Real-time factor: 6.263129756350096
# ✅ Audio generated in 655.81 seconds.
#    💾 File saved to: output/audio/quick_test_commentary.wav
# 🔊 Playing audio...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 12
#       9     os.makedirs(os.path.dirname(save_file_path), exist_ok=True)
#      11     # Run the entire pipeline using the notebook function
# ---> 12     pipeline.process_pgn_for_notebook(
#      13         pgn_string=pgn_data,
#      14         play_audio=True,
#      15         save_path=save_file_path,
#      16         language='en'
#      17     )
#      18     print(f"--- Pipeline finished. Audio saved to {save_file_path} ---")
#      19 else:
#
# File c:\Users\Aagam\OneDrive\Desktop\ipd\model\newknight_speakai\chess_ai_commentary\src\pipeline.py:119, in ChessCommentaryPipeline.process_pgn_for_notebook(self, pgn_string, play_audio, save_path, language)
#     116     os.makedirs(os.path.dirname(save_path), exist_ok=True)
#     117     print(f"   📂 Output directory ensured: {os.path.dirname(save_path)}")
# --> 119 audio_file_path = self.voice_generator.generate_and_play(
#     120     full_commentary,
#     121     output_path=save_path,
#     122     language=language_code
#     123 )
#     125 if not audio_file_path:
#     126     print("❌ Voice generation step failed.")
#
# File c:\Users\Aagam\OneDrive\Desktop\ipd\model\newknight_speakai\chess_ai_commentary\src\voice_generator.py:94, in VoiceGenerator.generate_and_play(self, text, output_path, language)
#      91     print(f"   💾 File saved to: {output_path}")
#      93     # Play the generated audio
# ---> 94     self.play_audio(output_path)
#      96     return output_path
#      98 except Exception as e:
#
# File c:\Users\Aagam\OneDrive\Desktop\ipd\model\newknight_speakai\chess_ai_commentary\src\voice_generator.py:121, in VoiceGenerator.play_audio(self, audio_path)
#     119     pygame.mixer.music.play()
#     120     while pygame.mixer.music.get_busy():
# --> 121         time.sleep(0.1)
#     122     print("✅ Playback finished.")
#     123 except Exception as e:
#
# KeyboardInterrupt:
